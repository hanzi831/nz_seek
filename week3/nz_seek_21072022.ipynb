# %% [markdown]
# # NZ_Admin_JOBS Data Wrangling Task

# %%
#loading library
import numpy as np
import pandas as pd

# %%
#loading the dataset
jobs=pd.read_excel("NZ_Admin_JOBS.xlsx")

# %% [markdown]
# ## 1. Check the dataset

# %%
#check the first few rows 
jobs.head()
# Out:
#                                     字段1  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                             字段1_link  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                         字段2  \
# 0                                       NaN
# 1                      Avenues Orthodontics
# 2                        New Zealand Police
# 3  Kew Pacific Island Early Learning Centre
# 4                                       NaN
#
#                                                  字段3  \
# 0  location: Bay of PlentyBay of Plentyarea: Taur...
# 1  location: Bay of PlentyBay of Plentyarea: Taur...
# 2                         location: AucklandAuckland
# 3  location: SouthlandSouthlandarea: Invercargill...
# 4  location: CanterburyCanterburyarea: Christchur...
#
#                               字段4  \
# 0  Featured,at,Private Advertiser
# 1                     Featured,at
# 2                       4d ago,at
# 3                       1h ago,at
# 4    4d ago,at,Private Advertiser
#
#                                                  字段5
# 0  classification: Administration & Office Suppor...
# 1  classification: Administration & Office Suppor...
# 2  classification: Administration & Office Suppor...
# 3  classification: Administration & Office Suppor...
# 4  classification: Administration & Office Suppor...

# %%
jobs.shape
# Out:
# (2708, 6)

# %%
#Change the columns name
jobs=jobs.rename(columns={"字段1":"Job_title","字段1_link":"Job_link","字段2":"Company_name","字段3":"Location","字段4":"Date","字段5":"Classfication"})

# %%
jobs.head()
# Out:
#                               Job_title  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                             Job_link  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                Company_name  \
# 0                                       NaN
# 1                      Avenues Orthodontics
# 2                        New Zealand Police
# 3  Kew Pacific Island Early Learning Centre
# 4                                       NaN
#
#                                             Location  \
# 0  location: Bay of PlentyBay of Plentyarea: Taur...
# 1  location: Bay of PlentyBay of Plentyarea: Taur...
# 2                         location: AucklandAuckland
# 3  location: SouthlandSouthlandarea: Invercargill...
# 4  location: CanterburyCanterburyarea: Christchur...
#
#                              Date  \
# 0  Featured,at,Private Advertiser
# 1                     Featured,at
# 2                       4d ago,at
# 3                       1h ago,at
# 4    4d ago,at,Private Advertiser
#
#                                        Classfication
# 0  classification: Administration & Office Suppor...
# 1  classification: Administration & Office Suppor...
# 2  classification: Administration & Office Suppor...
# 3  classification: Administration & Office Suppor...
# 4  classification: Administration & Office Suppor...

# %%
#for job_title, we need to make the first alphabet is capital to unify the format 
jobs["Job_title"].str.capitalize()
# Out:
# 0                              Administrator
# 1                               Receptionist
# 2               Prosecutions support officer
# 3       Early childhood centre administrator
# 4             Business support administrator
#                         ...
# 2703                     Key account manager
# 2704                     Executive assistant
# 2705                  Temporary office roles
# 2706                  Temporary office roles
# 2707                     Executive assistant
# Name: Job_title, Length: 2708, dtype: object

# %%
#check the missing value
jobs.isna().any()
# Out:
# Job_title        False
# Job_link         False
# Company_name      True
# Location         False
# Date             False
# Classfication    False
# dtype: bool

# %% [markdown]
# ### There are only missing values in company_name column. We could locate to the rows that contain the missing values.

# %%
null_data = jobs[jobs.isnull().any(axis=1)]

# %%
null_data
# Out:
#                                              Job_title  \
# 0                                        Administrator
# 4                       Business Support Administrator
# 19                                       Administrator
# 60                                       Administrator
# 64            ADMINISTRATION SPECIALIST - CONSTRUCTION
# 67                                       Administrator
# 71                                       Administrator
# 95                                Export Admin Support
# 135                                Executive Assistant
# 187                     PERSONAL ASSISTANT - PART TIME
# 215                Time Target Rostering Administrator
# 297              Operations Coordinator - South Island
# 318                      Customer Service /Sales/Admin
# 385                                     Client Liaison
# 412  Executive Business Coordinator Cadetship - Gra...
# 437                    Receptionist / Office Assistant
# 446                                       Receptionist
# 470        Personal Assistant / Accounts Administrator
# 510                                   Customer Service
# 560                         Client Side Office Manager
# 623                                 Personal Assistant
# 656                           Card Fulfillment Officer
#
#                                               Job_link Company_name  \
# 0    https://www.seek.co.nz/job/50582301?type=promo...          NaN
# 4    https://www.seek.co.nz/job/50622432?type=stand...          NaN
# 19   https://www.seek.co.nz/job/50604829?type=stand...          NaN
# 60   https://www.seek.co.nz/job/50582301?type=stand...          NaN
# 64   https://www.seek.co.nz/job/50638765?type=stand...          NaN
# 67   https://www.seek.co.nz/job/50582301?type=promo...          NaN
# 71   https://www.seek.co.nz/job/50607763?type=stand...          NaN
# 95   https://www.seek.co.nz/job/50583111?type=stand...          NaN
# 135  https://www.seek.co.nz/job/50613522?type=stand...          NaN
# 187  https://www.seek.co.nz/job/50588220?type=stand...          NaN
# 215  https://www.seek.co.nz/job/50572487?type=stand...          NaN
# 297  https://www.seek.co.nz/job/50597654?type=stand...          NaN
# 318  https://www.seek.co.nz/job/50557862?type=stand...          NaN
# 385  https://www.seek.co.nz/job/50580821?type=stand...          NaN
# 412  https://www.seek.co.nz/job/50621110?type=stand...          NaN
# 437  https://www.seek.co.nz/job/50508458?type=stand...          NaN
# 446  https://www.seek.co.nz/job/50516951?type=stand...          NaN
# 470  https://www.seek.co.nz/job/50564784?type=stand...          NaN
# 510  https://www.seek.co.nz/job/50532433?type=stand...          NaN
# 560  https://www.seek.co.nz/job/50534335?type=stand...          NaN
# 623  https://www.seek.co.nz/job/50481163?type=stand...          NaN
# 656  https://www.seek.co.nz/job/50513472?type=stand...          NaN
#
#                                               Location  \
# 0    location: Bay of PlentyBay of Plentyarea: Taur...
# 4    location: CanterburyCanterburyarea: Christchur...
# 19   location: ManawatuManawatuarea: Rest of Manawa...
# 60   location: Bay of PlentyBay of Plentyarea: Taur...
# 64   location: AucklandAucklandarea: Rodney & North...
# 67   location: Bay of PlentyBay of Plentyarea: Taur...
# 71   location: AucklandAucklandarea: Rodney & North...
# 95   location: Hawkes BayHawkes Bayarea: HastingsHa...
# 135  location: AucklandAucklandarea: Manukau & East...
# 187  location: AucklandAucklandarea: Auckland Centr...
# 215  location: WaikatoWaikatoarea: Rest of WaikatoR...
# 297  location: CanterburyCanterburyarea: Christchur...
# 318  location: AucklandAucklandarea: Rodney & North...
# 385  location: TaranakiTaranakiarea: New PlymouthNe...
# 412  location: AucklandAucklandarea: Manukau & East...
# 437  location: AucklandAucklandarea: Auckland Centr...
# 446  location: WellingtonWellingtonarea: Hutt Valle...
# 470  location: Bay of PlentyBay of Plentyarea: Roto...
# 510  location: AucklandAucklandarea: Rodney & North...
# 560  location: AucklandAucklandarea: Auckland Centr...
# 623  location: AucklandAucklandarea: Manukau & East...
# 656  location: AucklandAucklandarea: Auckland Centr...
#
#                                Date  \
# 0    Featured,at,Private Advertiser
# 4      4d ago,at,Private Advertiser
# 19     7d ago,at,Private Advertiser
# 60    11d ago,at,Private Advertiser
# 64     5h ago,at,Private Advertiser
# 67   Featured,at,Private Advertiser
# 71     6d ago,at,Private Advertiser
# 95    11d ago,at,Private Advertiser
# 135    5d ago,at,Private Advertiser
# 187   10d ago,at,Private Advertiser
# 215   12d ago,at,Private Advertiser
# 297    7d ago,at,Private Advertiser
# 318   14d ago,at,Private Advertiser
# 385   11d ago,at,Private Advertiser
# 412    4d ago,at,Private Advertiser
# 437   24d ago,at,Private Advertiser
# 446   22d ago,at,Private Advertiser
# 470   13d ago,at,Private Advertiser
# 510   19d ago,at,Private Advertiser
# 560   19d ago,at,Private Advertiser
# 623   28d ago,at,Private Advertiser
# 656   24d ago,at,Private Advertiser
#
#                                          Classfication
# 0    classification: Administration & Office Suppor...
# 4    classification: Administration & Office Suppor...
# 19   classification: Administration & Office Suppor...
# 60   classification: Administration & Office Suppor...
# 64   classification: Administration & Office Suppor...
# 67   classification: Administration & Office Suppor...
# 71   classification: Administration & Office Suppor...
# 95   classification: Administration & Office Suppor...
# 135  classification: Administration & Office Suppor...
# 187  classification: Administration & Office Suppor...
# 215  classification: Administration & Office Suppor...
# 297  classification: Administration & Office Suppor...
# 318                                  $40,000 - $49,999
# 385  classification: Administration & Office Suppor...
# 412  classification: Administration & Office Suppor...
# 437  classification: Administration & Office Suppor...
# 446  classification: Administration & Office Suppor...
# 470  classification: Administration & Office Suppor...
# 510  classification: Administration & Office Suppor...
# 560                                 $40 - $45 per hour
# 623  classification: Administration & Office Suppor...
# 656                                  $45,000 - $54,999

# %% [markdown]
# ## 2. Data Wrangling
# ### 2.1 Column:Company_Name
# #### For column "Company_Name", I also unify the format as the first letter is upperletter.

# %%
jobs["Company_name"].str.capitalize()
# Out:
# 0                                            NaN
# 1                           Avenues orthodontics
# 2                             New zealand police
# 3       Kew pacific island early learning centre
# 4                                            NaN
#                           ...
# 2703                       Hays talent solutions
# 2704                      One eighty recruitment
# 2705                       Asset recruitment ltd
# 2706                       Asset recruitment ltd
# 2707                      Alpha recruitment - nz
# Name: Company_name, Length: 2708, dtype: object

# %% [markdown]
# ### 2.2 Column:Location
# #### For location, the ideal format is location:XX and add another column is area.
# #### However, within the value in column location, there are location, area and also salary, with is duplicated with the column classfication. So the first step is to clean the salary part within location column.

# %%
jobs["Location_new"]=jobs["Location"].str.split(",",n=1,expand=True)[0]

# %%
jobs["Location_new"]
# Out:
# 0       location: Bay of PlentyBay of Plentyarea: Taur...
# 1       location: Bay of PlentyBay of Plentyarea: Taur...
# 2                              location: AucklandAuckland
# 3       location: SouthlandSouthlandarea: Invercargill...
# 4       location: CanterburyCanterburyarea: Christchur...
#                               ...
# 2703    location: AucklandAucklandarea: Auckland Centr...
# 2704    location: WellingtonWellingtonarea: Wellington...
# 2705       location: WaikatoWaikatoarea: HamiltonHamilton
# 2706       location: WaikatoWaikatoarea: HamiltonHamilton
# 2707                       location: WellingtonWellington
# Name: Location_new, Length: 2708, dtype: object

# %% [markdown]
# ### The next step is to extract the salary part from column classfication and put into a new column calls salary.

# %%
jobs["Salary"]=jobs["Location"].str.split(",",n=1,expand=True)[1]

# %%
jobs["Salary"]
# Out:
# 0                              None
# 1                              None
# 2                              None
# 3                              None
# 4                              None
#                    ...
# 2703                           None
# 2704        Competitive hourly rate
# 2705    Competitive hourly rates $$
# 2706    Competitive hourly rates $$
# 2707                           None
# Name: Salary, Length: 2708, dtype: object

# %% [markdown]
# ### 2.3 Column: Area

# %% [markdown]
# ### Then extract the area part from location columns and build a new column "area".

# %%
jobs["Area"]=jobs["Location_new"].str.split("area: ",n=1,expand=True)[1]

# %%
jobs["Area"]
# Out:
# 0                           TaurangaTauranga
# 1                           TaurangaTauranga
# 2                                       None
# 3                   InvercargillInvercargill
# 4                   ChristchurchChristchurch
#                         ...
# 2703        Auckland CentralAuckland Central
# 2704    Wellington CentralWellington Central
# 2705                        HamiltonHamilton
# 2706                        HamiltonHamilton
# 2707                                    None
# Name: Area, Length: 2708, dtype: object

# %%
#Remove the duplicated words
def removeduplicated(x):
    if x!=None:
        trim=x.strip()
        index=(trim+trim).find(trim,1)
        if index==-1:
            return trim
        else:
            return trim[:index]
    if x==None:
        return None

# %%
jobs["Area"]=jobs["Area"].apply(lambda x:removeduplicated(x))

# %%
jobs["Area"]
# Out:
# 0                 Tauranga
# 1                 Tauranga
# 2                     None
# 3             Invercargill
# 4             Christchurch
#                ...
# 2703      Auckland Central
# 2704    Wellington Central
# 2705              Hamilton
# 2706              Hamilton
# 2707                  None
# Name: Area, Length: 2708, dtype: object

# %% [markdown]
# ### 2.4 Column: Location
# #### Now we start to clean the location.

# %%
jobs["Location_new"]=jobs["Location_new"].str.split("area: ",n=1,expand=True)[0]

# %%
jobs["Location_new"]
# Out:
# 0       location: Bay of PlentyBay of Plenty
# 1       location: Bay of PlentyBay of Plenty
# 2                 location: AucklandAuckland
# 3               location: SouthlandSouthland
# 4             location: CanterburyCanterbury
#                         ...
# 2703              location: AucklandAuckland
# 2704          location: WellingtonWellington
# 2705                location: WaikatoWaikato
# 2706                location: WaikatoWaikato
# 2707          location: WellingtonWellington
# Name: Location_new, Length: 2708, dtype: object

# %%
jobs["Location_new"]=jobs["Location_new"].str.split(": ",n=1,expand=True)[1]

# %%
jobs["Location_new"]=jobs["Location_new"].apply(lambda x:removeduplicated(x))

# %%
jobs["Location_new"]
# Out:
# 0       Bay of Plenty
# 1       Bay of Plenty
# 2            Auckland
# 3           Southland
# 4          Canterbury
#             ...
# 2703         Auckland
# 2704       Wellington
# 2705          Waikato
# 2706          Waikato
# 2707       Wellington
# Name: Location_new, Length: 2708, dtype: object

# %%
jobs
# Out:
#                                  Job_title  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                Job_link  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# 2703  https://www.seek.co.nz/job/50490062?type=stand...
# 2704  https://www.seek.co.nz/job/50488000?type=stand...
# 2705  https://www.seek.co.nz/job/50524865?type=stand...
# 2706  https://www.seek.co.nz/job/50477118?type=stand...
# 2707  https://www.seek.co.nz/job/50496571?type=stand...
#
#                                   Company_name  \
# 0                                          NaN
# 1                         Avenues Orthodontics
# 2                           New Zealand Police
# 3     Kew Pacific Island Early Learning Centre
# 4                                          NaN
# ...                                        ...
# 2703                     Hays Talent Solutions
# 2704                    one eighty recruitment
# 2705                     Asset Recruitment Ltd
# 2706                     Asset Recruitment Ltd
# 2707                    Alpha Recruitment - NZ
#
#                                                Location  \
# 0     location: Bay of PlentyBay of Plentyarea: Taur...
# 1     location: Bay of PlentyBay of Plentyarea: Taur...
# 2                            location: AucklandAuckland
# 3     location: SouthlandSouthlandarea: Invercargill...
# 4     location: CanterburyCanterburyarea: Christchur...
# ...                                                 ...
# 2703  location: AucklandAucklandarea: Auckland Centr...
# 2704  location: WellingtonWellingtonarea: Wellington...
# 2705  location: WaikatoWaikatoarea: HamiltonHamilton...
# 2706  location: WaikatoWaikatoarea: HamiltonHamilton...
# 2707                     location: WellingtonWellington
#
#                                 Date  \
# 0     Featured,at,Private Advertiser
# 1                        Featured,at
# 2                          4d ago,at
# 3                          1h ago,at
# 4       4d ago,at,Private Advertiser
# ...                              ...
# 2703                      27d ago,at
# 2704                      27d ago,at
# 2705                      20d ago,at
# 2706                      28d ago,at
# 2707                      26d ago,at
#
#                                           Classfication   Location_new  \
# 0     classification: Administration & Office Suppor...  Bay of Plenty
# 1     classification: Administration & Office Suppor...  Bay of Plenty
# 2     classification: Administration & Office Suppor...       Auckland
# 3     classification: Administration & Office Suppor...      Southland
# 4     classification: Administration & Office Suppor...     Canterbury
# ...                                                 ...            ...
# 2703  classification: Administration & Office Suppor...       Auckland
# 2704                            Competitive hourly rate     Wellington
# 2705                        Competitive hourly rates $$        Waikato
# 2706                        Competitive hourly rates $$        Waikato
# 2707  classification: Administration & Office Suppor...     Wellington
#
#                            Salary                Area
# 0                            None            Tauranga
# 1                            None            Tauranga
# 2                            None                None
# 3                            None        Invercargill
# 4                            None        Christchurch
# ...                           ...                 ...
# 2703                         None    Auckland Central
# 2704      Competitive hourly rate  Wellington Central
# 2705  Competitive hourly rates $$            Hamilton
# 2706  Competitive hourly rates $$            Hamilton
# 2707                         None                None
#
# [2708 rows x 9 columns]

# %%
# Remove location column 
jobs.drop("Location",inplace=True,axis=1)

# %%
jobs
# Out:
#                                  Job_title  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                Job_link  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# 2703  https://www.seek.co.nz/job/50490062?type=stand...
# 2704  https://www.seek.co.nz/job/50488000?type=stand...
# 2705  https://www.seek.co.nz/job/50524865?type=stand...
# 2706  https://www.seek.co.nz/job/50477118?type=stand...
# 2707  https://www.seek.co.nz/job/50496571?type=stand...
#
#                                   Company_name  \
# 0                                          NaN
# 1                         Avenues Orthodontics
# 2                           New Zealand Police
# 3     Kew Pacific Island Early Learning Centre
# 4                                          NaN
# ...                                        ...
# 2703                     Hays Talent Solutions
# 2704                    one eighty recruitment
# 2705                     Asset Recruitment Ltd
# 2706                     Asset Recruitment Ltd
# 2707                    Alpha Recruitment - NZ
#
#                                 Date  \
# 0     Featured,at,Private Advertiser
# 1                        Featured,at
# 2                          4d ago,at
# 3                          1h ago,at
# 4       4d ago,at,Private Advertiser
# ...                              ...
# 2703                      27d ago,at
# 2704                      27d ago,at
# 2705                      20d ago,at
# 2706                      28d ago,at
# 2707                      26d ago,at
#
#                                           Classfication   Location_new  \
# 0     classification: Administration & Office Suppor...  Bay of Plenty
# 1     classification: Administration & Office Suppor...  Bay of Plenty
# 2     classification: Administration & Office Suppor...       Auckland
# 3     classification: Administration & Office Suppor...      Southland
# 4     classification: Administration & Office Suppor...     Canterbury
# ...                                                 ...            ...
# 2703  classification: Administration & Office Suppor...       Auckland
# 2704                            Competitive hourly rate     Wellington
# 2705                        Competitive hourly rates $$        Waikato
# 2706                        Competitive hourly rates $$        Waikato
# 2707  classification: Administration & Office Suppor...     Wellington
#
#                            Salary                Area
# 0                            None            Tauranga
# 1                            None            Tauranga
# 2                            None                None
# 3                            None        Invercargill
# 4                            None        Christchurch
# ...                           ...                 ...
# 2703                         None    Auckland Central
# 2704      Competitive hourly rate  Wellington Central
# 2705  Competitive hourly rates $$            Hamilton
# 2706  Competitive hourly rates $$            Hamilton
# 2707                         None                None
#
# [2708 rows x 8 columns]

# %% [markdown]
# ### 2.5 Column:Date
# #### Then the column post_date is needed to be cleaned. My idea is to extract the time only and get rid of other words.

# %%
jobs["Post_date"]=jobs["Date"].str.split(",",n=1,expand=True)[0]

# %%
jobs["date_temp"]=jobs["Date"].str.split(",",n=2,expand=True)[2]

# %%
jobs["date_temp"]
# Out:
# 0       Private Advertiser
# 1                     None
# 2                     None
# 3                     None
# 4       Private Advertiser
#                ...
# 2703                  None
# 2704                  None
# 2705                  None
# 2706                  None
# 2707                  None
# Name: date_temp, Length: 2708, dtype: object

# %%
#Merge two columns
jobs["Company_name"]=jobs["Company_name"].fillna(jobs["date_temp"])

# %%
jobs["Company_name"]
# Out:
# 0                             Private Advertiser
# 1                           Avenues Orthodontics
# 2                             New Zealand Police
# 3       Kew Pacific Island Early Learning Centre
# 4                             Private Advertiser
#                           ...
# 2703                       Hays Talent Solutions
# 2704                      one eighty recruitment
# 2705                       Asset Recruitment Ltd
# 2706                       Asset Recruitment Ltd
# 2707                      Alpha Recruitment - NZ
# Name: Company_name, Length: 2708, dtype: object

# %%
def dateprocess(x):
    if x.strip()=="Featured":
        return None
    else:
        return x.split(" ")[0]

# %%
jobs["Post_date"]=jobs["Post_date"].apply(lambda x:dateprocess(x))

# %%
jobs["Post_date"]
# Out:
# 0       None
# 1       None
# 2         4d
# 3         1h
# 4         4d
#         ...
# 2703     27d
# 2704     27d
# 2705     20d
# 2706     28d
# 2707     26d
# Name: Post_date, Length: 2708, dtype: object

# %%
def datechange(x):
    if x!=None:
        if "h" in x:
            return "1d"
        if "m" in x:
            return str((int(x.strip("m")[0])*30))+"d"
        else:
            return x
    else:
        return None

# %%
jobs["Post_date"]=jobs["Post_date"].apply(lambda x:datechange(x))

# %%
jobs["Post_date"]=jobs["Post_date"].str[:-1]

# %%
# Remove temporary column 
jobs.drop("date_temp",inplace=True,axis=1)
jobs.drop("Date",inplace=True,axis=1)

# %%
jobs
# Out:
#                                  Job_title  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                Job_link  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# 2703  https://www.seek.co.nz/job/50490062?type=stand...
# 2704  https://www.seek.co.nz/job/50488000?type=stand...
# 2705  https://www.seek.co.nz/job/50524865?type=stand...
# 2706  https://www.seek.co.nz/job/50477118?type=stand...
# 2707  https://www.seek.co.nz/job/50496571?type=stand...
#
#                                   Company_name  \
# 0                           Private Advertiser
# 1                         Avenues Orthodontics
# 2                           New Zealand Police
# 3     Kew Pacific Island Early Learning Centre
# 4                           Private Advertiser
# ...                                        ...
# 2703                     Hays Talent Solutions
# 2704                    one eighty recruitment
# 2705                     Asset Recruitment Ltd
# 2706                     Asset Recruitment Ltd
# 2707                    Alpha Recruitment - NZ
#
#                                           Classfication   Location_new  \
# 0     classification: Administration & Office Suppor...  Bay of Plenty
# 1     classification: Administration & Office Suppor...  Bay of Plenty
# 2     classification: Administration & Office Suppor...       Auckland
# 3     classification: Administration & Office Suppor...      Southland
# 4     classification: Administration & Office Suppor...     Canterbury
# ...                                                 ...            ...
# 2703  classification: Administration & Office Suppor...       Auckland
# 2704                            Competitive hourly rate     Wellington
# 2705                        Competitive hourly rates $$        Waikato
# 2706                        Competitive hourly rates $$        Waikato
# 2707  classification: Administration & Office Suppor...     Wellington
#
#                            Salary                Area Post_date
# 0                            None            Tauranga      None
# 1                            None            Tauranga      None
# 2                            None                None         4
# 3                            None        Invercargill         1
# 4                            None        Christchurch         4
# ...                           ...                 ...       ...
# 2703                         None    Auckland Central        27
# 2704      Competitive hourly rate  Wellington Central        27
# 2705  Competitive hourly rates $$            Hamilton        20
# 2706  Competitive hourly rates $$            Hamilton        28
# 2707                         None                None        26
#
# [2708 rows x 8 columns]

# %% [markdown]
# ## 2.6 Column: Classfication and subclassfication
# #### By looking at classfication column, the words are duplicated. So the next step is to clean classfication column.

# %%
jobs["Subclassfication"]=jobs["Classfication"].str.split("subClassification: ",n=1,expand=True)[1]

# %%
jobs["Subclassfication"]=jobs["Subclassfication"].apply(lambda x:removeduplicated(x))

# %%
jobs["Subclassfication"]
# Out:
# 0                   Office Management
# 1                       Receptionists
# 2                               Other
# 3           Administrative Assistants
# 4       Client & Sales Administration
#                     ...
# 2703    Client & Sales Administration
# 2704                             None
# 2705                             None
# 2706                             None
# 2707             PA, EA & Secretarial
# Name: Subclassfication, Length: 2708, dtype: object

# %%
jobs["Classfication"]=jobs["Classfication"].str.split("subClassification: ",n=1,expand=True)[0]

# %%
jobs["Classfication"]=jobs["Classfication"].str.split("classification: ",n=1,expand=True)[1]

# %%
jobs["Classfication"]=jobs["Classfication"].apply(lambda x:removeduplicated(x))

# %%
jobs["Classfication"]
# Out:
# 0       Administration & Office Support
# 1       Administration & Office Support
# 2       Administration & Office Support
# 3       Administration & Office Support
# 4       Administration & Office Support
#                      ...
# 2703    Administration & Office Support
# 2704                               None
# 2705                               None
# 2706                               None
# 2707    Administration & Office Support
# Name: Classfication, Length: 2708, dtype: object

# %%
jobs
# Out:
#                                  Job_title  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                Job_link  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# 2703  https://www.seek.co.nz/job/50490062?type=stand...
# 2704  https://www.seek.co.nz/job/50488000?type=stand...
# 2705  https://www.seek.co.nz/job/50524865?type=stand...
# 2706  https://www.seek.co.nz/job/50477118?type=stand...
# 2707  https://www.seek.co.nz/job/50496571?type=stand...
#
#                                   Company_name  \
# 0                           Private Advertiser
# 1                         Avenues Orthodontics
# 2                           New Zealand Police
# 3     Kew Pacific Island Early Learning Centre
# 4                           Private Advertiser
# ...                                        ...
# 2703                     Hays Talent Solutions
# 2704                    one eighty recruitment
# 2705                     Asset Recruitment Ltd
# 2706                     Asset Recruitment Ltd
# 2707                    Alpha Recruitment - NZ
#
#                         Classfication   Location_new  \
# 0     Administration & Office Support  Bay of Plenty
# 1     Administration & Office Support  Bay of Plenty
# 2     Administration & Office Support       Auckland
# 3     Administration & Office Support      Southland
# 4     Administration & Office Support     Canterbury
# ...                               ...            ...
# 2703  Administration & Office Support       Auckland
# 2704                             None     Wellington
# 2705                             None        Waikato
# 2706                             None        Waikato
# 2707  Administration & Office Support     Wellington
#
#                            Salary                Area Post_date  \
# 0                            None            Tauranga      None
# 1                            None            Tauranga      None
# 2                            None                None         4
# 3                            None        Invercargill         1
# 4                            None        Christchurch         4
# ...                           ...                 ...       ...
# 2703                         None    Auckland Central        27
# 2704      Competitive hourly rate  Wellington Central        27
# 2705  Competitive hourly rates $$            Hamilton        20
# 2706  Competitive hourly rates $$            Hamilton        28
# 2707                         None                None        26
#
#                    Subclassfication
# 0                 Office Management
# 1                     Receptionists
# 2                             Other
# 3         Administrative Assistants
# 4     Client & Sales Administration
# ...                             ...
# 2703  Client & Sales Administration
# 2704                           None
# 2705                           None
# 2706                           None
# 2707           PA, EA & Secretarial
#
# [2708 rows x 9 columns]

# %% [markdown]
# ### 2.7 Column: Salary

# %%
jobs["Salary"]=jobs["Salary"][(jobs["Salary"].str.contains("\d"))==True]

# %%
jobs["Salary"]=jobs["Salary"].str.replace("to","-")

# %%
jobs["Salary"].unique()
# Out:
# array([nan, '$20 per hour', '$20 - $24.99 per hour', '$19 - $22 per hour',
#        '$40,000 - $49,999', '$25 per hour', '$60 000 - $70 000 per annum',
#        '$20.00 per hour', '$55,000 - $69,999', '$20.00 per hour.',
#        '$21 per hour', '$55,000 - $64,999',
#        '$50,000 - $55,000 plus benefits', '$45,000 - $49,999',
#        '$55,000 - $60,000 per annum pro rata', '$48,835 - $63,221',
#        '$20 - $29.99 per hour', '$24-$28', 'Up - $27ph', '8% holiday pay',
#        '$45,000 - $59,999', 'NZD25 - NZD28 per hour', '$22 per hour',
#        'NZD75000 per annum', '$75k - $85k p.a.',
#        '$24 - $25 + 8% holiday pay!', '$50,000 per annum.',
#        '$20 - $25 per hour', '$30 - $38 p.h. + 8% Holiday Pay',
#        '$45-$55,000', '$50,000 - $54,999',
#        'Up - $23 p.h. + + 8% Holiday Pay', 'Up - $22.00 p.h.',
#        'NZD69,726-94,127p.a.+Retirement contributions',
#        '$60k-$70k depending on experience!', '$22.00 - $23.00 phr',
#        '$27 - $33 p.h. + 8% holiday pay',
#        '$60K - $80K experience dependent',
#        '$60 - $65k + Career Progression - QS / leadership',
#        '$35 - $39.99 per hour',
#        '$20 - $24.99 per hour dependent on experience.',
#        'Up - $27 p.h. + 8% Holiday Pay', 'NZD19 - NZD23 per hour',
#        '$60,000 pa', '$21 - $25 p.h. + 8% Holiday Pay',
#        '$60,000 - $69,999', '$21-$23 per hour', '$50,000 - $59,999',
#        '$40 - $45 per hour', '$18.50 - $23.50 per hour', '$25.5',
#        'Up - $35 p.h. + 8% Holiday Pay',
#        '$21 - $22 p.h. + 8% Holiday Pay', 'NZD25 - NZD30 per hour',
#        '$25 - $29.99 per hour', '$50,000 - $69,999', '$50,000 - $64,999',
#        '$20 - $40 per hour', '$48,000 - $55,000',
#        '$50k - $65k p.a. + plus kiwisaver', '$70-$80k+Super',
#        '$20 - $30 per hour', '$45,000 - $54,999',
#        '$55,000 - $65,000 depending on relevant experience',
#        '$70-75k per annum', '$45,000 - $55,000 depending on experience',
#        '$24 - $28 p.h.  + 8% Holiday Pay',
#        '$35 - $40 p.h. + + 8% Holiday Pay', 'Circa 50k'], dtype=object)

# %%
jobs[["lower_salary","higher_salary"]]=jobs["Salary"].str.split("-",n=1,expand=True)

# %%
jobs["lower_salary"].unique()
# Out:
# array([nan, '$20 per hour', '$20 ', '$19 ', '$40,000 ', '$25 per hour',
#        '$60 000 ', '$20.00 per hour', '$55,000 ', '$20.00 per hour.',
#        '$21 per hour', '$50,000 ', '$45,000 ', '$48,835 ', '$24', 'Up ',
#        '8% holiday pay', 'NZD25 ', '$22 per hour', 'NZD75000 per annum',
#        '$75k ', '$24 ', '$50,000 per annum.', '$30 ', '$45', 'NZD69,726',
#        '$60k', '$22.00 ', '$27 ', '$60K ', '$60 ', '$35 ', 'NZD19 ',
#        '$60,000 pa', '$21 ', '$60,000 ', '$21', '$40 ', '$18.50 ',
#        '$25.5', '$25 ', '$48,000 ', '$50k ', '$70', 'Circa 50k'],
#       dtype=object)

# %%
jobs["lower_salary"]=jobs["lower_salary"].str.replace(r'([Kk])',"000")
# Out:
# <ipython-input-55-c1e41af9a25b>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   jobs["lower_salary"]=jobs["lower_salary"].str.replace(r'([Kk])',"000")

# %%
jobs["lower_salary"]=jobs["lower_salary"].str.replace(r'(8% holiday pay)',"")
# Out:
# <ipython-input-56-7e4b02752eb8>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   jobs["lower_salary"]=jobs["lower_salary"].str.replace(r'(8% holiday pay)',"")

# %%
jobs["lower_salary"]=jobs["lower_salary"].str.extract(r'(\d+\.\d.|\d+)')

# %%
jobs["lower_salary"].unique()
# Out:
# array([nan, '20', '19', '40', '25', '60', '20.00', '55', '21', '50', '45',
#        '48', '24', '22', '75000', '30', '69', '60000', '22.00', '27',
#        '35', '18.50', '50000', '70'], dtype=object)

# %%
jobs["higher_salary"].unique()
# Out:
# array([nan, None, ' $24.99 per hour', ' $22 per hour', ' $49,999',
#        ' $70 000 per annum', ' $69,999', ' $64,999',
#        ' $55,000 plus benefits', ' $60,000 per annum pro rata',
#        ' $63,221', ' $29.99 per hour', '$28', ' $27ph', ' $59,999',
#        ' NZD28 per hour', ' $85k p.a.', ' $25 + 8% holiday pay!',
#        ' $25 per hour', ' $38 p.h. + 8% Holiday Pay', '$55,000',
#        ' $54,999', ' $23 p.h. + + 8% Holiday Pay', ' $22.00 p.h.',
#        '94,127p.a.+Retirement contributions',
#        '$70k depending on experience!', ' $23.00 phr',
#        ' $33 p.h. + 8% holiday pay', ' $80K experience dependent',
#        ' $65k + Career Progression - QS / leadership', ' $39.99 per hour',
#        ' $24.99 per hour dependent on experience.',
#        ' $27 p.h. + 8% Holiday Pay', ' NZD23 per hour',
#        ' $25 p.h. + 8% Holiday Pay', '$23 per hour', ' $45 per hour',
#        ' $23.50 per hour', ' $35 p.h. + 8% Holiday Pay',
#        ' $22 p.h. + 8% Holiday Pay', ' NZD30 per hour', ' $40 per hour',
#        ' $55,000', ' $65k p.a. + plus kiwisaver', '$80k+Super',
#        ' $30 per hour', ' $65,000 depending on relevant experience',
#        '75k per annum', ' $55,000 depending on experience',
#        ' $28 p.h.  + 8% Holiday Pay', ' $40 p.h. + + 8% Holiday Pay'],
#       dtype=object)

# %%
jobs["higher_salary"]=jobs["higher_salary"].str.replace(r'([Kk])',"000")
# Out:
# <ipython-input-60-089b636ba17f>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   jobs["higher_salary"]=jobs["higher_salary"].str.replace(r'([Kk])',"000")

# %%
jobs["higher_salary"]=jobs["higher_salary"].str.replace(r'(8% [hH]oliday [pP]ay*)',"")
# Out:
# <ipython-input-61-05acb9d92b2d>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   jobs["higher_salary"]=jobs["higher_salary"].str.replace(r'(8% [hH]oliday [pP]ay*)',"")

# %%
jobs["higher_salary"].unique()
# Out:
# array([nan, None, ' $24.99 per hour', ' $22 per hour', ' $49,999',
#        ' $70 000 per annum', ' $69,999', ' $64,999',
#        ' $55,000 plus benefits', ' $60,000 per annum pro rata',
#        ' $63,221', ' $29.99 per hour', '$28', ' $27ph', ' $59,999',
#        ' NZD28 per hour', ' $85000 p.a.', ' $25 + !', ' $25 per hour',
#        ' $38 p.h. + ', '$55,000', ' $54,999', ' $23 p.h. + + ',
#        ' $22.00 p.h.', '94,127p.a.+Retirement contributions',
#        '$70000 depending on experience!', ' $23.00 phr', ' $33 p.h. + ',
#        ' $80000 experience dependent',
#        ' $65000 + Career Progression - QS / leadership',
#        ' $39.99 per hour', ' $24.99 per hour dependent on experience.',
#        ' $27 p.h. + ', ' NZD23 per hour', ' $25 p.h. + ', '$23 per hour',
#        ' $45 per hour', ' $23.50 per hour', ' $35 p.h. + ',
#        ' $22 p.h. + ', ' NZD30 per hour', ' $40 per hour', ' $55,000',
#        ' $65000 p.a. + plus 000iwisaver', '$80000+Super', ' $30 per hour',
#        ' $65,000 depending on relevant experience', '75000 per annum',
#        ' $55,000 depending on experience', ' $28 p.h.  + ',
#        ' $40 p.h. + + '], dtype=object)

# %%
jobs["higher_salary"]=jobs["higher_salary"].str.extract('(\d+\.\d+|\d+ \d+|\d+)')

# %%
jobs["higher_salary"]=jobs["higher_salary"].replace("70 000","70000")

# %%
jobs["higher_salary"].unique()
# Out:
# array([nan, '24.99', '22', '49', '70000', '69', '64', '55', '60', '63',
#        '29.99', '28', '27', '59', '85000', '25', '38', '54', '23',
#        '22.00', '94', '23.00', '33', '80000', '65000', '39.99', '45',
#        '23.50', '35', '30', '40', '65', '75000'], dtype=object)

# %%
def yeartohour(x):
    if float(x)>1000:
        return round(float(x)/(50*38),2)
    else:
        return x

# %%
jobs["higher_salary"]=jobs["higher_salary"].apply(lambda x:yeartohour(x))

# %%
jobs["higher_salary"].unique()
# Out:
# array([nan, '24.99', '22', '49', 36.84, '69', '64', '55', '60', '63',
#        '29.99', '28', '27', '59', 44.74, '25', '38', '54', '23', '22.00',
#        '94', '23.00', '33', 42.11, 34.21, '39.99', '45', '23.50', '35',
#        '30', '40', '65', 39.47], dtype=object)

# %%
jobs["lower_salary"]=jobs["lower_salary"].apply(lambda x:yeartohour(x))

# %%
jobs.head(20)
# Out:
#                                             Job_title  \
# 0                                       Administrator
# 1                                        Receptionist
# 2                        Prosecutions Support Officer
# 3                Early Childhood Centre Administrator
# 4                      Business Support Administrator
# 5                                     Support Officer
# 6                                     Support Officer
# 7                                office administrator
# 8                                Office Administrator
# 9                              Administration Officer
# 10                             Administration Officer
# 11                                         Data Entry
# 12            Office Admin Assistant (10hrs per week)
# 13                               Office Administrator
# 14                               Office Administrator
# 15                           Customer Service Officer
# 16           Administration Assistant - Mt Wellington
# 17  Part-time Health & Disability Administrative A...
# 18          Office Coordinator, Whangarei Youth Space
# 19                                      Administrator
#
#                                              Job_link  \
# 0   https://www.seek.co.nz/job/50582301?type=promo...
# 1   https://www.seek.co.nz/job/50620889?type=promo...
# 2   https://www.seek.co.nz/job/50622169?type=stand...
# 3   https://www.seek.co.nz/job/50639620?type=stand...
# 4   https://www.seek.co.nz/job/50622432?type=stand...
# 5   https://www.seek.co.nz/job/50640393?type=stand...
# 6   https://www.seek.co.nz/job/50615674?type=stand...
# 7   https://www.seek.co.nz/job/50640166?type=stand...
# 8   https://www.seek.co.nz/job/50639248?type=stand...
# 9   https://www.seek.co.nz/job/50629393?type=stand...
# 10  https://www.seek.co.nz/job/50600186?type=stand...
# 11  https://www.seek.co.nz/job/50616188?type=stand...
# 12  https://www.seek.co.nz/job/50597141?type=stand...
# 13  https://www.seek.co.nz/job/50632818?type=stand...
# 14  https://www.seek.co.nz/job/50632185?type=stand...
# 15  https://www.seek.co.nz/job/50614282?type=stand...
# 16  https://www.seek.co.nz/job/50638817?type=stand...
# 17  https://www.seek.co.nz/job/50610748?type=stand...
# 18  https://www.seek.co.nz/job/50633756?type=stand...
# 19  https://www.seek.co.nz/job/50604829?type=stand...
#
#                                        Company_name  \
# 0                                Private Advertiser
# 1                              Avenues Orthodontics
# 2                                New Zealand Police
# 3          Kew Pacific Island Early Learning Centre
# 4                                Private Advertiser
# 5                   Ministry for Primary Industries
# 6   Ministry of Business, Innovation and Employment
# 7                            Hepburn Electrical Ltd
# 8                               Webster Holland Ltd
# 9                                New Zealand Police
# 10                       Department of Conservation
# 11                                  Triple One Care
# 12   UIV Limited - Premier Insulation North Central
# 13                      Wraight and Associates Ltd.
# 14                  Morgan & Pollard Landscapes Ltd
# 15                                 CM Trailer Parts
# 16                                    Harvey Norman
# 17                                         LIFEWISE
# 18                            Whangarei Youth Space
# 19                               Private Advertiser
#
#                       Classfication   Location_new                 Salary  \
# 0   Administration & Office Support  Bay of Plenty                    NaN
# 1   Administration & Office Support  Bay of Plenty                    NaN
# 2   Administration & Office Support       Auckland                    NaN
# 3   Administration & Office Support      Southland                    NaN
# 4   Administration & Office Support     Canterbury                    NaN
# 5   Administration & Office Support      Northland                    NaN
# 6   Administration & Office Support     Wellington                    NaN
# 7   Administration & Office Support  Bay of Plenty                    NaN
# 8   Administration & Office Support  Bay of Plenty                    NaN
# 9   Administration & Office Support     Canterbury                    NaN
# 10  Administration & Office Support     West Coast                    NaN
# 11  Administration & Office Support         Tasman                    NaN
# 12                             None       Auckland           $20 per hour
# 13  Administration & Office Support     Wellington                    NaN
# 14  Administration & Office Support     Canterbury                    NaN
# 15  Administration & Office Support     Canterbury                    NaN
# 16  Administration & Office Support       Auckland                    NaN
# 17                             None       Auckland  $20 - $24.99 per hour
# 18  Administration & Office Support      Northland                    NaN
# 19  Administration & Office Support       Manawatu                    NaN
#
#                          Area Post_date               Subclassfication  \
# 0                    Tauranga      None              Office Management
# 1                    Tauranga      None                  Receptionists
# 2                        None         4                          Other
# 3                Invercargill         1      Administrative Assistants
# 4                Christchurch         4  Client & Sales Administration
# 5                   Whangarei       270      Administrative Assistants
# 6          Wellington Central         5                          Other
# 7                     Rotorua       210      Administrative Assistants
# 8                    Tauranga         1      Administrative Assistants
# 9                        None         3                          Other
# 10         Rest of West Coast         7      Administrative Assistants
# 11                     Nelson         5   Data Entry & Word Processing
# 12    Manukau & East Auckland         8                           None
# 13         Wellington Central         3              Office Management
# 14         Rest of Canterbury         3      Administrative Assistants
# 15  Timaru & South Canterbury         5  Client & Sales Administration
# 16           Auckland Central         1      Administrative Assistants
# 17           Auckland Central         6                           None
# 18                  Whangarei         3      Administrative Assistants
# 19           Rest of Manawatu         7                          Other
#
#    lower_salary higher_salary
# 0           NaN           NaN
# 1           NaN           NaN
# 2           NaN           NaN
# 3           NaN           NaN
# 4           NaN           NaN
# 5           NaN           NaN
# 6           NaN           NaN
# 7           NaN           NaN
# 8           NaN           NaN
# 9           NaN           NaN
# 10          NaN           NaN
# 11          NaN           NaN
# 12           20           NaN
# 13          NaN           NaN
# 14          NaN           NaN
# 15          NaN           NaN
# 16          NaN           NaN
# 17           20         24.99
# 18          NaN           NaN
# 19          NaN           NaN

# %%
jobs=jobs.rename(columns={"Location_new":"Location","Salary":"Salary_Range"})

# %%
jobs = jobs[['Job_title', 'Job_link', 'Company_name', 'Location', 'Area',"Post_date","Classfication","Subclassfication","lower_salary","higher_salary","Salary_Range"]]

# %%
jobs.head(20)
# Out:
#                                             Job_title  \
# 0                                       Administrator
# 1                                        Receptionist
# 2                        Prosecutions Support Officer
# 3                Early Childhood Centre Administrator
# 4                      Business Support Administrator
# 5                                     Support Officer
# 6                                     Support Officer
# 7                                office administrator
# 8                                Office Administrator
# 9                              Administration Officer
# 10                             Administration Officer
# 11                                         Data Entry
# 12            Office Admin Assistant (10hrs per week)
# 13                               Office Administrator
# 14                               Office Administrator
# 15                           Customer Service Officer
# 16           Administration Assistant - Mt Wellington
# 17  Part-time Health & Disability Administrative A...
# 18          Office Coordinator, Whangarei Youth Space
# 19                                      Administrator
#
#                                              Job_link  \
# 0   https://www.seek.co.nz/job/50582301?type=promo...
# 1   https://www.seek.co.nz/job/50620889?type=promo...
# 2   https://www.seek.co.nz/job/50622169?type=stand...
# 3   https://www.seek.co.nz/job/50639620?type=stand...
# 4   https://www.seek.co.nz/job/50622432?type=stand...
# 5   https://www.seek.co.nz/job/50640393?type=stand...
# 6   https://www.seek.co.nz/job/50615674?type=stand...
# 7   https://www.seek.co.nz/job/50640166?type=stand...
# 8   https://www.seek.co.nz/job/50639248?type=stand...
# 9   https://www.seek.co.nz/job/50629393?type=stand...
# 10  https://www.seek.co.nz/job/50600186?type=stand...
# 11  https://www.seek.co.nz/job/50616188?type=stand...
# 12  https://www.seek.co.nz/job/50597141?type=stand...
# 13  https://www.seek.co.nz/job/50632818?type=stand...
# 14  https://www.seek.co.nz/job/50632185?type=stand...
# 15  https://www.seek.co.nz/job/50614282?type=stand...
# 16  https://www.seek.co.nz/job/50638817?type=stand...
# 17  https://www.seek.co.nz/job/50610748?type=stand...
# 18  https://www.seek.co.nz/job/50633756?type=stand...
# 19  https://www.seek.co.nz/job/50604829?type=stand...
#
#                                        Company_name       Location  \
# 0                                Private Advertiser  Bay of Plenty
# 1                              Avenues Orthodontics  Bay of Plenty
# 2                                New Zealand Police       Auckland
# 3          Kew Pacific Island Early Learning Centre      Southland
# 4                                Private Advertiser     Canterbury
# 5                   Ministry for Primary Industries      Northland
# 6   Ministry of Business, Innovation and Employment     Wellington
# 7                            Hepburn Electrical Ltd  Bay of Plenty
# 8                               Webster Holland Ltd  Bay of Plenty
# 9                                New Zealand Police     Canterbury
# 10                       Department of Conservation     West Coast
# 11                                  Triple One Care         Tasman
# 12   UIV Limited - Premier Insulation North Central       Auckland
# 13                      Wraight and Associates Ltd.     Wellington
# 14                  Morgan & Pollard Landscapes Ltd     Canterbury
# 15                                 CM Trailer Parts     Canterbury
# 16                                    Harvey Norman       Auckland
# 17                                         LIFEWISE       Auckland
# 18                            Whangarei Youth Space      Northland
# 19                               Private Advertiser       Manawatu
#
#                          Area Post_date                    Classfication  \
# 0                    Tauranga      None  Administration & Office Support
# 1                    Tauranga      None  Administration & Office Support
# 2                        None         4  Administration & Office Support
# 3                Invercargill         1  Administration & Office Support
# 4                Christchurch         4  Administration & Office Support
# 5                   Whangarei       270  Administration & Office Support
# 6          Wellington Central         5  Administration & Office Support
# 7                     Rotorua       210  Administration & Office Support
# 8                    Tauranga         1  Administration & Office Support
# 9                        None         3  Administration & Office Support
# 10         Rest of West Coast         7  Administration & Office Support
# 11                     Nelson         5  Administration & Office Support
# 12    Manukau & East Auckland         8                             None
# 13         Wellington Central         3  Administration & Office Support
# 14         Rest of Canterbury         3  Administration & Office Support
# 15  Timaru & South Canterbury         5  Administration & Office Support
# 16           Auckland Central         1  Administration & Office Support
# 17           Auckland Central         6                             None
# 18                  Whangarei         3  Administration & Office Support
# 19           Rest of Manawatu         7  Administration & Office Support
#
#                  Subclassfication lower_salary higher_salary  \
# 0               Office Management          NaN           NaN
# 1                   Receptionists          NaN           NaN
# 2                           Other          NaN           NaN
# 3       Administrative Assistants          NaN           NaN
# 4   Client & Sales Administration          NaN           NaN
# 5       Administrative Assistants          NaN           NaN
# 6                           Other          NaN           NaN
# 7       Administrative Assistants          NaN           NaN
# 8       Administrative Assistants          NaN           NaN
# 9                           Other          NaN           NaN
# 10      Administrative Assistants          NaN           NaN
# 11   Data Entry & Word Processing          NaN           NaN
# 12                           None           20           NaN
# 13              Office Management          NaN           NaN
# 14      Administrative Assistants          NaN           NaN
# 15  Client & Sales Administration          NaN           NaN
# 16      Administrative Assistants          NaN           NaN
# 17                           None           20         24.99
# 18      Administrative Assistants          NaN           NaN
# 19                          Other          NaN           NaN
#
#              Salary_Range
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
# 9                     NaN
# 10                    NaN
# 11                    NaN
# 12           $20 per hour
# 13                    NaN
# 14                    NaN
# 15                    NaN
# 16                    NaN
# 17  $20 - $24.99 per hour
# 18                    NaN
# 19                    NaN

# %% [markdown]
# ### 3. Save as excel

# %%
jobs.to_excel("admin_nz_14072022.xlsx",index=False)
